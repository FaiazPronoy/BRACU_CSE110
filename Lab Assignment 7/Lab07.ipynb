# %%
#Task_01
my_list=[10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]
for idx in range(len(my_list)):
  for idx2 in range(len(my_list)-1):
    if my_list[idx2+1] < my_list[idx2]:
      temp = my_list[idx2]
      my_list[idx2] = my_list[idx2+1]
      my_list[idx2+1] = temp
print(my_list)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#Task_02
my_list=[10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]
for item in range(len(my_list)):
    min_value=my_list[item]
    min_index=item
    for value in range(item+1,len(my_list)):
        if my_list[value]<min_value:
            min_value=my_list[value]
            min_index=value
    temp=my_list[min_index]
    my_list[min_index]=my_list[item]
    my_list[item]=temp
print(my_list)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#Task_03
list1=[10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]
for idx in range(len(list1)):
  for idx2 in range(len(list1)-1):
    if list1[idx2+1] > list1[idx2]:
      temp = list1[idx2]
      list1[idx2] = list1[idx2+1]
      list1[idx2+1] = temp
print(list1)
# Out:
# [29, 20, 18, 17, 15, 14, 12, 11, 10, 6, 5, 3, 2, 2, 1]

# %%
#TASK_04

lst= [10,30,20,70,11,15,22,16,58,100,12,56,70,80]

for a in range(len(lst)-1):
  if a%2==0:
    min_val= lst[a]
    min_ind=a
    for b in range(a+1,len(lst)):
      if b%2 == 0:
        if lst[b] < min_val:
          min_val=lst[b]
          min_ind=b
    temp=lst[a]
    lst[a]=min_val
    lst[min_ind]=temp
  else:
    min_val = lst[a]
    min_ind=a
    for i in range(a+1,len(lst)):
      if i %2 !=0:
        if lst[i]>min_val:
          min_val= lst[i]
          min_ind=i
    temp=lst[a]
    lst[a]=min_val
    lst[min_ind]=temp
print(lst)
# Out:
# [10, 100, 11, 80, 12, 70, 20, 56, 22, 30, 58, 16, 70, 15]

# %%
#Task_05

lst = [ ["Alan", 95, 87, 91], ["Turing", 92, 90, 83], ["Elon", 87, 92, 80], ["Musk", 85, 94, 90] ]

user = input()
idx = ""
if user == "CSE110":
  idx = 1
elif user == "PHY111":
  idx = 2
elif user == "MAT110":
  idx = 3

for iter in range(0, len(lst)-1):
  min_idx = iter
  for n in range(iter+1, len(lst)):
    if lst[n][idx] > lst[min_idx][idx]:
      min_idx =  n
  lst[iter], lst[min_idx]  =  lst[min_idx], lst[iter]
  
for i in range(len(lst)):
  print(lst[i][0])
# Out:
# Musk
# Elon
# Turing
# Alan

# %%
#Task_06
list1 = [4,2,3,1,6,5]
original_list = list1.copy()
for idx in range(len(list1)):
      for idx2 in range(len(list1)-1):
            if list1[idx2+1] < list1[idx2]:
                temp = list1[idx2]
                list1[idx2] = list1[idx2+1]
                list1[idx2+1] = temp
counter = 0
for i in range(len(list1)):
    if list1[i] != original_list[i]:
        counter+=1

print(counter)
# Out:
# 4

# %%
#Task_07
list_one= [1, 7, 9, 10]
list_two= [2, 7, 6, 5]


new_list=list_one+list_two
sorted_newlist=sorted(new_list)
print('Sorted list =',sorted_newlist)
length=len(sorted_newlist)

if length%2!=0:
    num=int((length+1)/2)

    print('Median=',sorted_newlist[num-1])
else:
    index= int((length)//2)-1
    index1=int(((length)/2)+1)
    median=float((sorted_newlist[index]+sorted_newlist[index1])/2)
    print('Median =',median)
# Out:
# Sorted list = [1, 2, 5, 6, 7, 7, 9, 10]
# Median = 6.5

# %%
#Task_08
list_one =  [-10, 15, 2, 4, -4, 7, -8]

diff = 99999999999
for i in range(len(list_one)-1):
    for j in range(i+1, len(list_one)):
        sum = list_one[i] + list_one[j] 

        if abs(sum) < diff:
            diff  = abs(sum)
            a = list_one[i]
            b = list_one[j]
        break
print(f"Two pairs which have the smallest sum = {a} and {b}")
# Out:
# Two pairs which have the smallest sum = 4 and -4

# %%
#Task_09
given_points = [(5,3), (2,9), (-2,7), (-3,-4), (0,6), (7,-2)]

temp = 999999999999
a = 0
b = 0

for iter in given_points:
  position = ((iter[0]**2)+(iter[1]**2))**.5
  if position < temp:
      temp = position
      a = iter[0]
      b = iter[1]
  

print(f"Minimum Distance = {temp}")
print(f"Here the closest point is ({a},{b}) which has a distance of {temp} from the origin.")
# Out:
# Minimum Distance = 5.0
# Here the closest point is (-3,-4) which has a distance of 5.0 from the origin.
